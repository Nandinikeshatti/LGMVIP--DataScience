# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Nandini\\Desktop\\datasets'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Nandini\\Desktop\\datasets'

# %%
img=cv2.imread("puppy.jpg")
plt.imshow(img)

# %%
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1365 at 0x1F272DA4C70>

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_img))
# Out:
# <PIL.Image.Image image mode=L size=2048x1365 at 0x1F2752519A0>

# %%
inv_gray_img = 255-gray_img

# %%
inv_gray_img
# Out:
# array([[131, 131, 131, ..., 154, 154, 154],
#        [132, 132, 131, ..., 154, 154, 154],
#        [133, 133, 133, ..., 154, 154, 154],
#        ...,
#        [198, 198, 199, ..., 166, 166, 166],
#        [198, 198, 199, ..., 166, 166, 166],
#        [198, 198, 199, ..., 166, 166, 166]], dtype=uint8)

# %%
display(Image.fromarray(inv_gray_img))
# Out:
# <PIL.Image.Image image mode=L size=2048x1365 at 0x1F275C437C0>

# %%
blur_img=cv2.GaussianBlur(inv_gray_img, (35,35),0)

# %%
display(Image.fromarray(blur_img))
# Out:
# <PIL.Image.Image image mode=L size=2048x1365 at 0x1F275C43D00>

# %%
img=255-blur_img
def dodge(gray_imablur_img):
    return cv2.divide(gray_img, img, scale = 400.0)

# %%
pencil_sketch=dodge(img)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=2048x1365 at 0x1F275251970>
